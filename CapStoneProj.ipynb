# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Data_Final.csv')
data.shape
# Out:
# (16719, 16)

# %%
pd.DataFrame(data)
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
data.dropna(inplace=True)

# %%
data['Genre'].unique()
# Out:
# array(['Sports', 'Racing', 'Platform', 'Misc', 'Action', 'Puzzle',
#        'Shooter', 'Fighting', 'Simulation', 'Role-Playing', 'Adventure',
#        'Strategy'], dtype=object)

# %%
data = data[data['Year_of_Release']>2010]
data
# Out:
#                                     Name Platform  Year_of_Release     Genre  \
# 16                    Grand Theft Auto V      PS3           2013.0    Action
# 23                    Grand Theft Auto V     X360           2013.0    Action
# 29        Call of Duty: Modern Warfare 3     X360           2011.0   Shooter
# 34            Call of Duty: Black Ops II      PS3           2012.0   Shooter
# 35            Call of Duty: Black Ops II     X360           2012.0   Shooter
# ...                                  ...      ...              ...       ...
# 16634           Sebastien Loeb Rally Evo     XOne           2016.0    Racing
# 16656                   Fast Racing Neo      WiiU           2016.0    Action
# 16696  Metal Gear Solid V: Ground Zeroes       PC           2014.0    Action
# 16700                             Breach       PC           2011.0   Shooter
# 16706            STORM: Frontline Nation       PC           2011.0  Strategy
#
# ...

# %%
data.drop_duplicates(inplace=True)
data.reset_index(level=None, drop=True, inplace=True, col_level=0, col_fill='')
print(data['Year_of_Release'].unique())
print(data['Platform'].unique())
data
# Out:
# [2013. 2011. 2012. 2014. 2015. 2016.]
# ['PS3' 'X360' '3DS' 'PS4' 'Wii' 'WiiU' 'XOne' 'PC' 'PSV' 'DS' 'PSP']
#                                    Name Platform  Year_of_Release     Genre  \
# 0                    Grand Theft Auto V      PS3           2013.0    Action
# 1                    Grand Theft Auto V     X360           2013.0    Action
# 2        Call of Duty: Modern Warfare 3     X360           2011.0   Shooter
# 3            Call of Duty: Black Ops II      PS3           2012.0   Shooter
# 4            Call of Duty: Black Ops II     X360           2012.0   Shooter
# ...                                 ...      ...              ...       ...
# 1711           Sebastien Loeb Rally Evo     XOne           2016.0    Racing
# 1712                   Fast Racing Neo      WiiU           2016.0    Action
# 1713  Metal Gear Solid V: Ground Zeroes       PC           2014.0    Action
# 1714                             Breach       PC           2011.0   Shooter
# ...

# %%
Globalsales = data.drop(['NA_Sales','EU_Sales','JP_Sales','Other_Sales','Publisher','Developer','Year_of_Release','Rating'],axis=1)
Globalsales
# Out:
#                                    Name Platform     Genre  Global_Sales  \
# 0                    Grand Theft Auto V      PS3    Action         21.04
# 1                    Grand Theft Auto V     X360    Action         16.27
# 2        Call of Duty: Modern Warfare 3     X360   Shooter         14.73
# 3            Call of Duty: Black Ops II      PS3   Shooter         13.79
# 4            Call of Duty: Black Ops II     X360   Shooter         13.67
# ...                                 ...      ...       ...           ...
# 1711           Sebastien Loeb Rally Evo     XOne    Racing          0.01
# 1712                   Fast Racing Neo      WiiU    Action          0.01
# 1713  Metal Gear Solid V: Ground Zeroes       PC    Action          0.01
# 1714                             Breach       PC   Shooter          0.01
# 1715            STORM: Frontline Nation       PC  Strategy          0.01
#
#       Critic_Score  Critic_Count  User_Score  User_Count
# ...

# %%
UsablePlatform = ['PS3','X360','PS4','Wii','XOne','PC']
SumarizedPlatform = pd.DataFrame()
for i in UsablePlatform:
    SumarizedPlatform = SumarizedPlatform.append(Globalsales[Globalsales['Platform'] == i])

print(SumarizedPlatform['Platform'].unique())
SumarizedPlatform
# Out:
# ['PS3' 'X360' 'PS4' 'Wii' 'XOne' 'PC']
#                                    Name Platform     Genre  Global_Sales  \
# 0                    Grand Theft Auto V      PS3    Action         21.04
# 3            Call of Duty: Black Ops II      PS3   Shooter         13.79
# 5        Call of Duty: Modern Warfare 3      PS3   Shooter         13.32
# 13                 Call of Duty: Ghosts      PS3   Shooter          9.36
# 17                       FIFA Soccer 13      PS3    Action          8.16
# ...                                 ...      ...       ...           ...
# 1704                             Ride 2       PC    Racing          0.01
# 1708    Transformers: Fall of Cybertron       PC    Action          0.01
# 1713  Metal Gear Solid V: Ground Zeroes       PC    Action          0.01
# 1714                             Breach       PC   Shooter          0.01
# 1715            STORM: Frontline Nation       PC  Strategy          0.01
#
# ...

# %%
SumarizedPlatform.dropna(inplace=True)

# %%
SumarizedPlatform.sort_values('Genre',inplace=True)
SumarizedPlatform.set_index('Genre')
# Out:
#                                       Name Platform  Global_Sales  \
# Genre
# Action                  Grand Theft Auto V      PS3         21.04
# Action                      X-Men: Destiny      Wii          0.10
# Action      Metal Gear Rising: Revengeance      PS3          1.42
# Action                     Disney Universe      Wii          1.02
# Action               Infamous: First Light      PS4          0.03
# ...                                    ...      ...           ...
# Strategy  StarCraft II: Heart of the Swarm       PC          1.67
# Strategy                            XCOM 2       PC          0.23
# Strategy                         Tropico 4       PC          0.27
# Strategy             Angry Birds Star Wars     XOne          0.16
# Strategy           STORM: Frontline Nation       PC          0.01
#
#           Critic_Score  Critic_Count  User_Score  User_Count
# Genre
# Action            97.0          50.0         8.2      3994.0
# ...

# %%
tmp = SumarizedPlatform.groupby('Genre').max()
tmpmin = SumarizedPlatform.groupby('Genre').min()

# %%
plt.bar([i for i in range(12)],tmp['Critic_Score'],width=0.25,color='#FCB08A')
plt.bar([i+0.25 for i in range(12)],tmpmin['Critic_Score'],width=0.25,color='#FEFAD4')
plt.xticks(rotation=90)
plt.xticks([i+0.125 for i in range(12)],tmp.index)
plt.xlabel('Game\'s Genre')
plt.ylabel('Critics_Score')
plt.title('Min and Max Critics_Score by Genre')
plt.show()

# %%
tmpavg = SumarizedPlatform.groupby('Genre').mean()
tmpavg['Critic_Score']/=10
tmpavg
# Out:
#               Global_Sales  Critic_Score  Critic_Count  User_Score  \
# Genre
# Action            0.888441      7.148201     33.702638    6.795683
# Adventure         0.394545      7.384091     31.727273    7.536364
# Fighting          0.509600      7.076000     32.666667    6.814667
# Misc              0.875273      7.127273     22.763636    6.865455
# Platform          0.575128      7.538462     37.076923    6.805128
# Puzzle            0.030000      8.800000     31.000000    8.400000
# Racing            0.493367      7.181633     30.204082    6.281633
# Role-Playing      0.785649      7.431298     39.290076    6.999237
# Shooter           1.418788      7.324675     41.047619    6.396537
# Simulation        0.335250      6.330000     22.525000    6.095000
# Sports            0.996832      7.359627     25.807453    5.872671
# Strategy          0.289231      7.502564     34.974359    6.658974
#
#                User_Count
# Genre
# Action         466.839329
# ...

# %%
plt.scatter(tmpavg.index,tmpavg['Critic_Score'],color='#FDD2B5',linewidth=2.5,label='Critics_Rating')
plt.scatter(tmpavg.index,tmpavg['User_Score'],color= '#DBE8C2',linewidth=2.5,label='Users_Rating')
plt.legend()
plt.xticks(rotation=90)
plt.xlabel('Game\'s Genre')
plt.ylabel('Critics_Score')
plt.title('Average Critics_Score by Genre')
plt.show()

# %%
disploting = sns.displot(data=SumarizedPlatform, x='Genre', y='Critic_Score',legend=True,aspect=1.75,color='#EFEDE7')
disploting.set_ylabels(label='Critics_Rating')
disploting.set_xticklabels(x='Genre', rotation=90)
disploting.set(title = "Critics_Rating Vs. Genre Heatmap")

# %%
disploting2 = sns.displot(data=SumarizedPlatform, x='Genre', y='User_Score',legend=True,aspect=1.75,color='grey')
disploting2.set_ylabels(label='Users_Rating')
disploting2.set_xticklabels(x='Genre', rotation=90)
disploting2.set(title = "Users_Rating Vs. Genre Heatmap")

# %%
SumarizedPlatform.index.value_counts()
# Out:
# 0       1
# 1543    1
# 1539    1
# 1534    1
# 590     1
#        ..
# 1535    1
# 760     1
# 745     1
# 583     1
# 1715    1
# Length: 1331, dtype: int64

# %%
sales3m = SumarizedPlatform[SumarizedPlatform['Global_Sales']>3]
globalsale = sns.stripplot(data=sales3m,x='Global_Sales',y='Genre',hue='Genre')
globalsale.set(xlabel='Global_Sales (Million)')
# Out:
# [Text(0.5, 0, 'Global_Sales (Million)')]
